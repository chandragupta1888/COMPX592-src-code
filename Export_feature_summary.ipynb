# %%
import pandas as pd

# Read the summary Excel file
df_raw = pd.read_excel("Testrun-summ.xlsx", sheet_name=0)

df_raw.head()
# Out:
#                                              Process features as input  \
# 0  PSO feature selection with split, No filter me...                51
# 1                   PSO + all features without split                51
# 2                Variance Threshold + PSO (testrun3)                51
# 3                       Mutual Info + Pso (testrun4)                51
# 4                      Anova F test + PSO (testrun5)                51
#
#    Features selected Time taken F1 Score      Unnamed: 6  Unnamed: 7  \
# 0               26.0    31 mins        - NaN         NaN         NaN
# 1              597.0    6.5 hrs        - NaN         NaN         NaN
# 2               22.0    29 mins   0.9998 NaN         NaN         NaN
# 3               22.0    35 mins   0.9998 NaN         NaN         NaN
# 4               16.0    35 mins   0.9998 NaN         NaN         NaN
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10 Unnamed: 11
# 0         NaN         NaN          NaN         NaN
# ...

# %%
# Select the block that contains your methods (adjust row indices if needed)
df = df_raw.iloc[1:10, 0:5].copy()

# Rename columns to simple names
df.columns = [
    "method",
    "n_input_features",
    "n_selected_features",
    "time_taken",
    "f1_score",
]

df
# Out:
#                                               method n_input_features  \
# 1                   PSO + all features without split               51
# 2                Variance Threshold + PSO (testrun3)               51
# 3                       Mutual Info + Pso (testrun4)               51
# 4                      Anova F test + PSO (testrun5)               51
# 5                        Chi Sqaure + PSO (testrun6)               51
# 6                               RFE + PSO (testrun7)               51
# 7  Random Forest Feature Importance + PSO (testrun8)               51
# 8                       Correlation + PSO (testrun9)               51
# 9                                   Correlation ONLY
#
#    n_selected_features time_taken f1_score
# 1                597.0    6.5 hrs        -
# 2                 22.0    29 mins   0.9998
# 3                 22.0    35 mins   0.9998
# 4                 16.0    35 mins   0.9998
# 5                 20.0    30 mins   0.9919
# ...

# %%
df.to_csv("feature_methods_summary.csv", index=False)
df
# Out:
#                                               method n_input_features  \
# 1                   PSO + all features without split               51
# 2                Variance Threshold + PSO (testrun3)               51
# 3                       Mutual Info + Pso (testrun4)               51
# 4                      Anova F test + PSO (testrun5)               51
# 5                        Chi Sqaure + PSO (testrun6)               51
# 6                               RFE + PSO (testrun7)               51
# 7  Random Forest Feature Importance + PSO (testrun8)               51
# 8                       Correlation + PSO (testrun9)               51
# 9                                   Correlation ONLY
#
#    n_selected_features time_taken f1_score
# 1                597.0    6.5 hrs        -
# 2                 22.0    29 mins   0.9998
# 3                 22.0    35 mins   0.9998
# 4                 16.0    35 mins   0.9998
# 5                 20.0    30 mins   0.9919
# ...
